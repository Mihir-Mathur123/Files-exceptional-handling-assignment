# %% [markdown]
# Q.1) What is the difference between interpreted and compiled languages?--
#
# 🔹 Compiled Languages
# Code is translated into machine code (binary) by a compiler before execution.
#
# The result is a standalone executable file.
#
# Faster at runtime since it's already compiled.
#
# Example languages: C, C++, Rust, Go
#
# Pros:
#
# Faster performance
#
# Early error detection during compilation
#
# Cons:
#
# Less flexible during development (need to recompile after every change)
#
# 🔹 Interpreted Languages
# Code is executed line-by-line by an interpreter at runtime.
#
# No separate executable is created.
#
# Slower at runtime, but easier to test and debug.
#
# Example languages: Python, JavaScript, Ruby
#
# Pros:
#
# Easier to test and debug
#
# More flexible for scripting and rapid development
#
# Cons:
#
# Slower execution
#
# Runtime errors only show during execution

# %% [markdown]
# Q.2)What is exception handling in Python?--
#
# ✅ What is Exception Handling in Python?
# Exception handling in Python is a mechanism that allows you to gracefully manage errors that occur during program execution, instead of letting the program crash.

# %%
try:
    # Code that might raise an exception
    x = 10 / 0
except ZeroDivisionError:
    # Code that runs if the exception occurs
    print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %% [markdown]
# Q.3)What is the purpose of the finally block in exception handling?
#
# The finally block in Python's exception handling is used to define code that will always execute, no matter whether an exception was raised or not.
#
# 🔹 Key Purpose:
# The finally block is typically used for cleanup operations that need to be performed regardless of what happens in the try or except blocks.
#
# It's often used to close files, release resources, or disconnect from a database, ensuring that the program doesn’t leave resources open or in an inconsistent state.

# %% [markdown]
# Q.4)What is logging in Python?--
#
# Logging in Python is the practice of recording events that occur during program execution. It allows you to track what is happening in your application, which is crucial for debugging, monitoring, and auditing. Unlike using print() for debugging, logging gives you more control over the output and can be configured to log at different levels of severity.
#
# 🔹 Why Use Logging?
# Debugging: Helps track down issues by recording the flow of your program.
#
# Monitoring: Logs events to monitor the health of your application in production.
#
# Auditing: Keeps a record of key events for auditing or compliance purposes.

# %% [markdown]
# Q.5)What is the significance of the __del__ method in Python?--
#
# The __del__ method is a special method (also known as a destructor) in Python that is called when an object is about to be destroyed or garbage collected. It is used to perform cleanup operations before the object’s memory is freed, such as closing files or releasing external resources.
#
# 🔹 Purpose:
# Resource Management: It helps in releasing resources like file handles, network connections, or database connections that an object may have acquired during its lifetime.
#
# Memory Management: Though Python uses automatic garbage collection (like reference counting and cyclic garbage collection), the __del__ method can be used for final cleanup if necessary.

# %% [markdown]
# Q.6)What is the difference between import and from ... import in Python?
# The difference between import and from ... import in Python lies in how you import modules and access their functions, classes, or variables. Here’s a breakdown:
#
# 1. import Statement
# When you use import, you import the entire module and must refer to its functions, classes, or variables with the module name as a prefix.
#
# Syntax:

# %%
import module_name

# %% [markdown]
# Example:

# %%
import math

# Accessing a function from the math module
result = math.sqrt(25)
print(result)
# Out:
# 5.0

# %% [markdown]
# Explanation: You import the entire math module and use the full module name (math) to access the sqrt function.

# %% [markdown]
# 2. from ... import Statement
# When you use from ... import, you import specific objects (functions, classes, variables) directly from the module into your current namespace, meaning you don’t need to prefix them with the module name.
#
# Syntax:

# %% [markdown]
# Example:

# %%
from math import sqrt

# No need to prefix with 'math'
result = sqrt(25)
print(result)
# Out:
# 5.0

# %% [markdown]
# Q,7)How can you handle multiple exceptions in Python?
# ✅ How to Handle Multiple Exceptions in Python
# In Python, you can handle multiple exceptions using the try and except blocks in several ways. This allows your program to handle different types of errors in specific ways, depending on the situation.
#
# 🔹 1. Handling Multiple Exceptions in Separate except Blocks
# You can have multiple except blocks to catch different types of exceptions and handle each one differently.
#
# Example:

# %%
try:
    x = int(input("Enter a number: "))
    result = 10 / x
except ZeroDivisionError:
    print("Error: Division by zero is not allowed!")
except ValueError:
    print("Error: Invalid input! Please enter a valid number.")
except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# Enter a number: 10000

# %% [markdown]
# Q.8)What is the purpose of the with statement when handling files in Python?
# ✅ Purpose of the with Statement When Handling Files in Python
# The with statement in Python is used for resource management and automatic cleanup. It ensures that files are properly opened and closed even if an exception occurs, which makes it particularly useful for working with files. The with statement is also known as a context manager.

# %% [markdown]
# Q.9)What is the difference between multithreading and multiprocessing?
# ✅ Difference Between Multithreading and Multiprocessing in Python
# Both multithreading and multiprocessing are techniques used to achieve concurrency or parallelism in Python programs, but they work in fundamentally different ways. Here’s a breakdown of each and the differences between them:
#
# 🔹 1. Multithreading
# Multithreading involves running multiple threads within a single process. Threads are smaller units of a process that share the same memory space but can execute independently.
#
# Use Case: Multithreading is useful when you have tasks that are I/O-bound, such as reading/writing files, network requests, or handling user input, where the program is often waiting for external resources.
#
# 🔹 2. Multiprocessing
# Multiprocessing involves running multiple processes, each with its own memory space. Unlike threads, processes do not share memory; each process has its own Python interpreter and its own GIL.
#
# Use Case: Multiprocessing is useful for CPU-bound tasks, like heavy computations or data processing, where you need to take full advantage of multiple CPU cores.

# %% [markdown]
# Q.10)What are the advantages of using logging in a program?
# ✅ Advantages of Using Logging in a Program
# Using logging in a program provides several significant advantages over simply using print() statements for tracking program behavior. Here's a breakdown of the benefits:
#
# 🔹 1. Persistent Record of Events
# Logging provides a persistent record of events, which can be stored in a log file. This is crucial for tracking program activity and identifying issues later, especially in production environments.
#
# Example:
# You might want to log the start time of a process, any exceptions that occur, and the final result. If something goes wrong, having logs allows you to go back and investigate.
#
# 🔹 2. Better Debugging and Troubleshooting
# Log files can provide detailed information about errors, warnings, and program flow. This makes debugging easier and faster because you can trace exactly what happened before an error occurred.
#
# Example:
# Logging can help you capture stack traces, the values of variables, and which functions were executed at a particular time.

# %% [markdown]
# Q.11)What is memory management in Python?
# ✅ Memory Management in Python
# Memory management in Python refers to the process of allocating and deallocating memory for objects and variables used during the execution of a program. Python uses an automatic memory management system that handles most of the work, making it easy for developers to focus on the core functionality of their programs.
#
# Here’s an overview of how memory management works in Python:
#
# 🔹 1. Memory Allocation in Python
# When you create an object in Python, the interpreter automatically allocates memory for that object. For example, when you create a variable or a complex data structure like a list, Python dynamically allocates memory for it.
#
# Example:

# %%
a = 10  # Allocates memory for the integer 10
b = [1, 2, 3]  # Allocates memory for the list

# %% [markdown]
# 🔹 2. The Role of the Python Memory Manager
# Python’s memory management is handled by the Python Memory Manager, which is responsible for allocating and deallocating memory for various types of objects, such as integers, strings, and custom objects.
#
# It maintains a private heap where all Python objects and data structures are stored. The memory manager interacts with the garbage collector to ensure that memory is freed when no longer needed.
#
# 🔹 3. Memory Pooling
# Python uses a technique called memory pooling to manage memory efficiently. Objects that have the same size (like small integers or strings) are grouped into pools. This reduces the overhead of repeatedly allocating and freeing memory.
#
# Example:
# Small integers (between -5 and 256) are often preallocated and reused, rather than allocating new memory every time.

# %% [markdown]
# Q.12)What are the basic steps involved in exception handling in Python?
# ✅ Basic Steps Involved in Exception Handling in Python
# Exception handling in Python is a way to gracefully handle errors that might occur during the execution of a program. It allows you to catch and manage exceptions (errors) that would otherwise cause the program to crash.
#
# Here are the basic steps involved in exception handling in Python:
#
# 🔹 1. try Block:
# The try block is where you put the code that may raise an exception. This is the part of the program where you suspect an error might occur. If an exception occurs inside the try block, Python will look for an except block to handle it.
#
# 🔹 2. except Block:
# The except block is used to catch and handle the exception raised in the try block. You can specify the type of exception you want to catch (e.g., ValueError, ZeroDivisionError), or use a general except to catch any exception.

# %% [markdown]
# Q.13)Why is memory management important in Python?--
# ✅ Why Memory Management is Important in Python
# Memory management is a critical aspect of any programming language, including Python. Efficient memory management ensures that a program runs optimally, doesn't waste resources, and avoids issues like memory leaks or slowdowns. Let's break down why memory management is important in Python:
#
# 🔹 1. Prevents Memory Leaks
# A memory leak occurs when a program continues to allocate memory but fails to release it when it’s no longer needed. Over time, memory leaks can cause an application to consume all available memory, leading to crashes, slowdowns, or system failures.
#
# How Python Helps: Python uses automatic garbage collection and reference counting to track and manage memory, which helps prevent memory leaks.
#
# Why It’s Important: Without proper memory management, even small leaks can accumulate over time, leading to inefficient use of system resources.
#
# Example:
# If Python didn't handle memory management, objects that are no longer in use could still be consuming memory, which would eventually cause performance degradation or crashes.
#
# 🔹 2. Efficient Resource Utilization
# Memory management ensures that the program uses the system's memory in an efficient manner. This is especially important for programs that need to handle large datasets, such as data analysis or machine learning applications.
#
# How Python Helps: Python optimizes memory usage using techniques like memory pooling for small objects (e.g., integers between -5 and 256 are pre-allocated), and garbage collection to automatically clean up unused objects.
#
# Why It’s Important: Efficient memory usage prevents the application from consuming unnecessary resources and keeps the system running smoothly.
#
# Example:
# If Python didn't manage memory efficiently, programs would consume more RAM than necessary, especially when handling large objects or datasets, which could impact the performance of the entire system.

# %% [markdown]
# Q.14)What is the role of try and except in exception handling?--
#
# ✅ Role of try and except in Exception Handling
# In Python, try and except blocks are fundamental components of exception handling. They work together to help manage errors in a controlled manner, preventing your program from crashing when it encounters unexpected situations or exceptions.
#
# Here’s a breakdown of their roles:
#
# 🔹 1. The try Block:
# The try block is where you write the code that might raise an exception. You place any operation that you think could fail (e.g., dividing by zero, accessing a file, or parsing invalid input) inside the try block.
#
# Purpose: It "tries" to execute the code and monitors for exceptions that might occur during its execution.
#
# If an exception occurs, Python immediately jumps to the corresponding except block to handle it.
#
# If no exception occurs, the program continues running normally after the try block.
#
# 🔹 2. The except Block:
# The except block is responsible for handling the exception if one occurs in the try block. When an error is encountered in the try block, Python jumps to the except block and attempts to handle the exception in a controlled manner.
#
# Purpose: It defines what should happen if a specific exception occurs. It allows you to respond to errors in a way that doesn’t cause the program to crash.
#
# You can catch specific exceptions (e.g., ValueError, ZeroDivisionError), or use a generic except block to catch any exception.

# %% [markdown]
# Q.15)How does Python's garbage collection system work?--
#
# ✅ How Python's Garbage Collection System Works
# Python uses an automatic garbage collection system to manage memory and ensure efficient usage of resources during the program's execution. The garbage collector is responsible for identifying and freeing memory occupied by objects that are no longer needed, thus preventing memory leaks and improving performance.
#
# Let’s break down how Python’s garbage collection works.
#
# 🔹 1. Reference Counting (Primary Method)
# Python uses a reference counting technique as the primary mechanism for managing memory. Each object in Python has an associated reference count, which tracks how many references point to that object.
#
# Reference Count: Every time an object is referenced (i.e., assigned to a variable or passed as a function argument), its reference count is incremented. When the reference goes out of scope or is deleted, the count is decremented.
#
# Example:

# %%
import sys

a = [1, 2, 3]  # Reference count for the list object increases by 1
b = a  # Reference count for the list object increases by 1
print(sys.getrefcount(a))  # Output: 3 (a, b, and sys.getrefcount refer to the same object)
del a  # Reference count for the list object decreases by 1
print(sys.getrefcount(b))  # Output: 2 (b and sys.getrefcount still refer to the object)
# Out:
# 3
# 2

# %% [markdown]
# When the reference count reaches zero, meaning no references to the object exist anymore, Python automatically deallocates the memory occupied by the object.
#
# 🔹 2. Problems with Reference Counting
# While reference counting is simple and efficient, it has some limitations, the most notable being the problem of circular references.
#
# Example of Circular References:

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

# Creating circular reference
node1 = Node(1)
node2 = Node(2)
node1.next = node2
node2.next = node1

# %% [markdown]
# In this case, both node1 and node2 reference each other. When the program goes out of scope, reference counting will not be able to detect that these objects are no longer needed because each still holds a reference to the other.
#
# This leads to memory leaks since Python won't be able to automatically deallocate their memory.

# %% [markdown]
# Q.16)What is the purpose of the else block in exception handling?--
#
# ✅ Purpose of the else Block in Exception Handling
# In Python’s exception handling mechanism, the else block is used to define code that should be executed only if no exceptions were raised in the try block. It provides a way to separate normal execution flow from error-handling code.
#
# 🔹 Key Points About the else Block
# The else block is optional, and it only runs if the try block completes without raising any exceptions.
#
# It allows you to write code that should run only when no errors occur in the try block, improving readability by separating successful logic from error handling logic.
#
# It is a good practice to put the code that does not raise exceptions in the else block, so that it is clear which part of the code is designed to run in the "no-exception" case.

# %% [markdown]
# Q.17)What are the common logging levels in Python?--
#
# ✅ Common Logging Levels in Python
# In Python, the logging module provides a powerful way to track events that happen during the execution of your program. The logging levels are used to define the severity of the messages you log. These levels allow you to control the verbosity of the logs, making it easier to filter out unnecessary details during development or production.
#
# Here are the common logging levels in Python:
#
# 🔹 1. DEBUG (Level 10)
# Purpose: The DEBUG level is used to log detailed information that is mostly useful for developers while diagnosing problems. These are the most granular messages.
#
# When to use: Use this level for debugging information such as variable values, control flow, or function entry/exit points.
#
# Example:

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
logging.debug('This is a debug message.')

# %% [markdown]
# 🔹 2. INFO (Level 20)
# Purpose: The INFO level is used to log informational messages that highlight the progress of the application in a general way. These messages provide a high-level overview of the system's execution.
#
# When to use: Use it for routine operations or milestones in the program (e.g., start or end of a task, configuration details, or important system events).
#
# Example:

# %%
logging.basicConfig(level=logging.INFO)
logging.info('This is an informational message.')

# %% [markdown]
# Q.18)What is the difference between os.fork() and multiprocessing in Python?--
#
# ✅ Difference Between os.fork() and multiprocessing in Python
# Both os.fork() and the multiprocessing module are used for creating parallel processes in Python, but they work differently and are used in different scenarios. Let’s dive into the key differences:
#
# 🔹 1. os.fork()
# What It Is:
# os.fork() is a system call that creates a new process by duplicating the calling process. The new process created is a child process, and the calling process is the parent process.
#
# 🔹 2. multiprocessing Module
# What It Is:
# The multiprocessing module is a higher-level API in Python designed to create and manage multiple processes. It allows you to create parallel processes that run independently, enabling the CPU to use multiple cores effectively.

# %% [markdown]
# Q.19)What is the importance of closing a file in Python?--
#
# ✅ Importance of Closing a File in Python
# Closing a file in Python is an essential step that you should take after you’re done working with a file. The close() method in Python is used to close a file, releasing any resources associated with it, and making sure that any changes made to the file are properly saved.
#
# Here’s why closing a file is important:
#
# 🔹 1. Releasing System Resources
# File handles and system resources (like memory) are allocated when you open a file. Each file opened consumes a file descriptor, which is a limited system resource.
#
# If files are not properly closed, you might run out of these file descriptors, leading to resource leaks and potentially hanging processes.
#
# For example:
#
# If you open too many files without closing them, your program might hit the system's file descriptor limit.
#
# On Unix-based systems (like Linux), this limit can be fairly low, leading to an OSError if the system cannot allocate more file descriptors.
#
# 🔹 2. Ensuring Data Integrity
# When you write data to a file, Python buffers the data (i.e., keeps it in memory temporarily) before actually writing it to disk.
#
# If you forget to close the file, any changes made might not be flushed (saved) to the file. This can result in partial data, corrupted files, or lost information.
#
# Calling close() ensures that all data is written out from the buffer and stored properly in the file

# %% [markdown]
# Q.20)What is the difference between file.read() and file.readline() in Python?--
#
# ✅ Difference Between file.read() and file.readline() in Python
# Both file.read() and file.readline() are methods used to read from files in Python, but they have different behaviors and use cases. Here's an overview of how they differ:
#
# 🔹 1. file.read()
# Purpose:
# The read() method reads the entire contents of a file (or a specified number of bytes) and returns it as a single string.
#
# 🔹 2. file.readline()
# Purpose:
# The readline() method reads the next line from the file each time it is called. It returns a string containing the contents of one line, including the newline character (\n) at the end of the line.

# %% [markdown]
# Q.21)What is the logging module in Python used for?--
#
# ✅ The logging Module in Python
# The logging module in Python is a built-in library used to log messages from your application. It provides a flexible framework for recording log messages from your code, which can be useful for debugging, monitoring, auditing, and keeping track of events during program execution.
#
# Logging is an essential practice for any software application, as it allows you to monitor the behavior of your code, detect issues, and track system performance, especially in production environments.
#
# 🔹 Key Features of the logging Module:
# Log Levels: Log messages can be categorized based on their severity (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
# Output Locations: Logs can be directed to different outputs like console, files, network sockets, or external services.
#
# Log Format: You can customize the format of log messages (e.g., include timestamps, log level, etc.).
#
# Multiple Handlers: Multiple handlers allow logs to be sent to different outputs (like both a file and the console at the same time).

# %% [markdown]
# Q.22)What is the os module in Python used for in file handling?--
#
# ✅ The os Module in Python for File Handling
# The os module in Python provides a way to interact with the operating system, offering a variety of functions to manipulate files, directories, and paths, and to perform other system-related operations.
#
# When it comes to file handling, the os module provides functions to perform tasks like:
#
# Creating, deleting, and renaming files and directories
#
# Checking file and directory properties
#
# Managing file paths and directories
#
# Performing file and directory operations in a platform-independent way
#
# It acts as an interface between the Python code and the operating system, making it easier to manage files and directories without worrying about the underlying operating system.
#
# 🔹 Key File-Handling Functions in the os Module
# Here are some important functions from the os module that are commonly used for file and directory operations:
#
# 🔸 1. os.rename(src, dst)
# Purpose: Renames a file or directory from src to dst.
#
# Usage: You can rename or move a file using this function.

# %% [markdown]
# 🔸 2. os.remove(path)
# Purpose: Deletes (removes) a file at the specified path.
#
# Usage: Use this to delete files. Make sure the file exists before deleting to avoid errors.

# %% [markdown]
# Q.23)What are the challenges associated with memory management in Python?--
#
# ✅ Challenges Associated with Memory Management in Python
# Memory management in Python is a crucial topic, as improper handling can lead to inefficient memory usage, slow performance, and even memory leaks. While Python’s automatic memory management (via garbage collection) makes it easier to manage memory compared to languages like C or C++, there are still several challenges developers face. These challenges are especially important when dealing with large datasets, long-running programs, or memory-constrained environments.
#
# Here are the key challenges associated with memory management in Python:
#
# 🔹 1. Memory Leaks
# A memory leak occurs when memory that is no longer needed is not released by the program, causing the memory usage to continuously increase.
#
# Cause: In Python, garbage collection handles memory deallocation, but if circular references are present (e.g., objects referring to each other), the garbage collector may not be able to reclaim memory.
#
# Solution: Use tools like gc (garbage collector module) to manually force the garbage collection process. Also, be mindful of circular references and use weak references (via weakref module) where applicable.
#
# 🔹 2. Object Lifetime Management
# In Python, the lifetime of an object (i.e., how long it stays in memory) is generally managed by reference counting and garbage collection, but it’s still difficult to precisely control when an object is removed from memory.
#
# Cause: When objects are no longer used but still referenced, they can remain in memory. This leads to memory bloat and can slow down the system.
#
# Solution: It's important to delete references explicitly using del or ensure that objects are no longer referenced. Also, use context managers (with the with statement) to manage resources properly.

# %% [markdown]
# Q.24) How do you raise an exception manually in Python?--
#
# ✅ Raising Exceptions Manually in Python
# In Python, you can raise exceptions manually using the raise keyword. This allows you to trigger an exception under specific conditions, even if no errors have occurred naturally in the program. Raising exceptions is a great way to signal that something unexpected or erroneous has happened, especially when validating inputs or handling unusual situations in your program.
#
# Here’s how to raise an exception in Python:
#
# 🔹 Basic Syntax of Raising an Exception
#
# 🔹 Raising Built-in Exceptions
# You can raise any of Python's built-in exceptions to signal different types of errors. Here's an example of raising a ValueError and TypeError:
#
# 🔹 Using raise with Conditions
# You can raise an exception only when a certain condition is met. For example, if a function receives invalid input, you might raise an exception:

# %% [markdown]
# Q.25)Why is it important to use multithreading in certain applications?--
#
# ✅ Why is it Important to Use Multithreading in Certain Applications?
# Multithreading is a powerful concept in concurrent programming where a single process is divided into multiple threads of execution. Each thread runs concurrently, allowing different parts of the program to execute simultaneously or in overlapping intervals. This can significantly improve the performance of certain types of applications, especially when they involve tasks that can be executed in parallel or require non-blocking operations.
#
# Let’s explore the importance of multithreading and the specific scenarios where it's particularly beneficial:
#
# 🔹 1. Improved Performance for I/O-bound Tasks
# One of the most common reasons to use multithreading is to improve performance in I/O-bound tasks. These tasks typically involve waiting for external resources, such as reading from disk, network requests, or waiting for user input. Multithreading helps by allowing other threads to run while one thread is waiting for I/O operations to complete.
#
# I/O-bound tasks: These tasks involve waiting for input/output operations to finish, such as reading from files, making network requests, or interacting with databases.
#
# Example:

# %%
import threading
import time

def download_data():
    print("Start downloading...")
    time.sleep(3)  # Simulating a network request
    print("Download complete!")

def process_data():
    print("Start processing...")
    time.sleep(2)  # Simulating a CPU-bound task
    print("Processing complete!")

# Without multithreading, we would have to wait for one to finish before starting the other
# With multithreading, both tasks can run concurrently
thread1 = threading.Thread(target=download_data)
thread2 = threading.Thread(target=process_data)

thread1.start()
thread2.start()

thread1.join()
thread2.join()
# Out:
# Start downloading...
# Start processing...
# Processing complete!
# Download complete!

# %% [markdown]
# In this example:
#
# download_data() simulates waiting for a network request.
#
# process_data() simulates a processing task that could run concurrently with the download.
#
# Without multithreading, you'd have to wait for the download to finish before starting the processing. With multithreading, both tasks can overlap, improving overall efficiency.

# %% [markdown]
# 2. Responsiveness in User Interface (UI) Applications
# In applications with a graphical user interface (GUI), it’s essential to keep the interface responsive while executing long-running tasks. Multithreading allows you to run background tasks without blocking the main thread, which is responsible for handling user input and updating the UI.
#
# For example, in a GUI application (like a desktop app built with Tkinter or PyQt), long-running tasks like downloading data, file processing, or image manipulation can be offloaded to separate threads to prevent the UI from freezing.
#
# Example: Using tkinter and Multithreading for Responsiveness
#
# 🔹 3. Handling Concurrent Requests in Web Servers
# In web servers or network applications, multithreading is crucial to handle multiple client requests concurrently. Without multithreading, the server would need to process requests sequentially, which can be inefficient and lead to long wait times for clients.
#
# Using multithreading, each incoming request can be handled by a separate thread, improving the responsiveness of the server and allowing it to serve many clients simultaneously.
#
# Example: Simple Multithreaded Web Server

# %% [markdown]
# Practical Questions

# %% [markdown]
# Q.1)How can you open a file for writing in Python and write a string to it?

# %% [markdown]
# 🔹 Example of Writing to a File:
# Here’s an example of how you can open a file and write a string to it:

# %%
# Open a file for writing (this will overwrite the file if it already exists)
with open('example.txt', 'w') as file:
    file.write("Hello, this is a string written to the file.")

print("String written to the file successfully.")
# Out:
# String written to the file successfully.

# %% [markdown]
# 🔹 Writing to a File Without Overwriting (Append Mode)
# If you want to append data to the file (instead of overwriting it), use the 'a' mode:

# %%
# Open a file for appending
with open('example.txt', 'a') as file:
    file.write("\nThis string will be appended to the file.")

print("String appended to the file successfully.")
# Out:
# String appended to the file successfully.

# %% [markdown]
# Q.2)Write a Python program to read the contents of a file and print each line.

# %%
# Open the file in read mode
file_path = 'your_file.txt'  # Replace with your file path

try:
    with open(file_path, 'r') as file:
        # Read and print each line in the file
        for line in file:
            print(line.strip())  # .strip() removes any extra newline characters
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
except IOError:
    print(f"Error: Unable to read the file '{file_path}'.")
# Out:
# Error: The file 'your_file.txt' was not found.

# %% [markdown]
# Q.3)How would you handle a case where the file doesn't exist while trying to open it for reading?
#
# In Python, when you try to open a file that doesn't exist, it raises a FileNotFoundError. You can handle this by using a try-except block to catch that exception and display a user-friendly message.
#
# Here’s an example of how you can handle the case where the file doesn’t exist:

# %%
file_path = 'your_file.txt'  # Replace with your file path

try:
    # Attempt to open the file in read mode
    with open(file_path, 'r') as file:
        # Read and print each line in the file
        for line in file:
            print(line.strip())  # .strip() removes any extra newline characters
except FileNotFoundError:
    print(f"Error: The file '{file_path}' does not exist.")
except IOError:
    print(f"Error: Unable to read the file '{file_path}'.")
# Out:
# Error: The file 'your_file.txt' does not exist.

# %% [markdown]
# Q.4)Write a Python script that reads from one file and writes its content to another file?

# %%
# Define the source and destination file paths
source_file_path = 'source_file.txt'  # Replace with your source file path
destination_file_path = 'destination_file.txt'  # Replace with your destination file path

try:
    # Open the source file in read mode and the destination file in write mode
    with open(source_file_path, 'r') as source_file:
        with open(destination_file_path, 'w') as destination_file:
            # Read each line from the source file and write it to the destination file
            for line in source_file:
                destination_file.write(line)

    print(f"Contents from '{source_file_path}' have been successfully copied to '{destination_file_path}'.")

except FileNotFoundError:
    print(f"Error: The file '{source_file_path}' was not found.")
except IOError:
    print(f"Error: Unable to read or write the file.")
# Out:
# Error: The file 'source_file.txt' was not found.

# %% [markdown]
# Q.5)How would you catch and handle division by zero error in Python?

# %%
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: Cannot divide by zero.

# %% [markdown]
# Q.6)Write a Python program that logs an error message to a log file when a division by zero exception occurs.

# %%
import logging

# Configure logging
logging.basicConfig(filename='error_log.txt', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def divide(a, b):
    try:
        return a / b
    except ZeroDivisionError as e:
        logging.error("Attempted to divide by zero: %s", e)
        print("An error occurred. Check the log file for details.")

# Example usage
num1 = 10
num2 = 0

result = divide(num1, num2)
# Out:
# ERROR:root:Attempted to divide by zero: division by zero
# An error occurred. Check the log file for details.

# %% [markdown]
# Q.7)How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging

# Configure the logging
logging.basicConfig(filename='app_log.txt', level=logging.DEBUG,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Logging messages at various levels
logging.debug("This is a DEBUG message.")
logging.info("This is an INFO message.")
logging.warning("This is a WARNING message.")
logging.error("This is an ERROR message.")
logging.critical("This is a CRITICAL message.")
# Out:
# WARNING:root:This is a WARNING message.
# ERROR:root:This is an ERROR message.
# CRITICAL:root:This is a CRITICAL message.

# %% [markdown]
# Q.8)Write a program to handle a file opening error using exception handling.

# %%
def read_file(filename):
    try:
        with open(filename, 'r') as file:
            contents = file.read()
            print("File Contents:\n", contents)
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except PermissionError:
        print(f"Error: Permission denied to open the file '{filename}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage
file_name = "non_existent_file.txt"
read_file(file_name)
# Out:
# Error: The file 'non_existent_file.txt' was not found.

# %% [markdown]
# Q.9)How can you read a file line by line and store its content in a list in Python?

# %%
file_path = "my_file.txt"  # Replace with your file path
lines = []

try:
    with open(file_path, 'r') as file:
        for line in file:
            lines.append(line.strip())  # .strip() removes leading/trailing whitespace, including newline characters
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

print(lines)
# Out:
# Error: The file 'my_file.txt' was not found.
# []

# %% [markdown]
# Q.10)How can you append data to an existing file in Python?

# %% [markdown]
# You can append data to an existing file in Python using the open() function with the append mode, denoted by the 'a' character.
#
# When you open a file in append mode:
#
# If the file exists, the new data will be written at the end of the file.
# If the file does not exist, a new file will be created.
# Here's how you can do it, along with important considerations:
#
# Basic Append Operation

# %%
file_path = "my_data.txt"
data_to_append = "\nThis is a new line of text." # Add a newline character to ensure it's on a new line

try:
    with open(file_path, 'a') as file:
        file.write(data_to_append)
    print(f"Data successfully appended to '{file_path}'")
except Exception as e:
    print(f"An error occurred: {e}")

# Verify the content (optional)
try:
    with open(file_path, 'r') as file:
        content = file.read()
        print("\nCurrent file content:")
        print(content)
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found after appending.")
except Exception as e:
    print(f"An error occurred while reading: {e}")
# Out:
# Data successfully appended to 'my_data.txt'
#
# Current file content:
#
# This is a new line of text.

# %% [markdown]
# Q.11)Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist?

# %% [markdown]
# When you try to access a dictionary key that doesn't exist in Python, it raises a KeyError. You can gracefully handle this using a try-except block.
#
# Here's a Python program demonstrating this:

# %%
def get_dictionary_value(my_dict, key):
    """
    Attempts to retrieve a value from a dictionary using a specified key.
    Uses a try-except block to handle KeyError if the key does not exist.

    Args:
        my_dict (dict): The dictionary to search in.
        key: The key to look for.

    Returns:
        The value associated with the key if found, otherwise None.
    """
    try:
        value = my_dict[key]
        print(f"Key '{key}' found. Value: {value}")
        return value
    except KeyError:
        print(f"Error: Key '{key}' not found in the dictionary.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# --- Test Cases ---

# 1. Dictionary with various data
my_data = {
    "name": "Alice",
    "age": 30,
    "city": "New York",
    "occupation": "Engineer"
}

print("--- Test Case 1: Existing Keys ---")
get_dictionary_value(my_data, "name")
get_dictionary_value(my_data, "age")
get_dictionary_value(my_data, "city")

print("\n--- Test Case 2: Non-Existing Key ---")
get_dictionary_value(my_data, "country") # This key does not exist
get_dictionary_value(my_data, "zip_code") # This key also does not exist

print("\n--- Test Case 3: Empty Dictionary ---")
empty_dict = {}
get_dictionary_value(empty_dict, "item")

print("\n--- Test Case 4: Key with None value (different from missing key) ---")
dict_with_none = {"status": None, "id": 123}
get_dictionary_value(dict_with_none, "status") # Key exists, value is None
get_dictionary_value(dict_with_none, "description") # Key does not exist
# Out:
# --- Test Case 1: Existing Keys ---
# Key 'name' found. Value: Alice
# Key 'age' found. Value: 30
# Key 'city' found. Value: New York
#
# --- Test Case 2: Non-Existing Key ---
# Error: Key 'country' not found in the dictionary.
# Error: Key 'zip_code' not found in the dictionary.
#
# --- Test Case 3: Empty Dictionary ---
# Error: Key 'item' not found in the dictionary.
#
# --- Test Case 4: Key with None value (different from missing key) ---
# Key 'status' found. Value: None
# Error: Key 'description' not found in the dictionary.

# %% [markdown]
# Q.12)Write a program that demonstrates using multiple except blocks to handle different types of exceptions.

# %% [markdown]
# Handling different types of exceptions gracefully is a crucial aspect of writing robust Python programs. By using multiple except blocks, you can provide specific error handling for various potential issues, making your code more resilient and user-friendly.
#
# Here's a program that demonstrates using multiple except blocks to handle different types of exceptions that might occur during a simple calculation involving user input:

# %%
def perform_division():
    """
    Prompts the user for two numbers and attempts to perform division.
    Uses multiple except blocks to handle specific errors like:
    - ValueError (if input is not a valid number)
    - ZeroDivisionError (if the second number is zero)
    - Exception (for any other unexpected errors)
    """
    print("--- Division Calculator ---")
    try:
        num1_str = input("Enter the first number: ")
        num2_str = input("Enter the second number: ")

        # Attempt to convert inputs to floats
        num1 = float(num1_str)
        num2 = float(num2_str)

        # Attempt to perform division
        result = num1 / num2
        print(f"Result of division: {num1} / {num2} = {result}")

    except ValueError:
        print("\nError: Invalid input. Please ensure you enter valid numbers.")
        print("Tip: Don't use text or leave the input blank.")

    except ZeroDivisionError:
        print("\nError: Cannot divide by zero! Please enter a non-zero second number.")

    except Exception as e:
        # This is a general catch-all for any other unexpected errors
        print(f"\nAn unexpected error occurred: {e}")
        print("Something went wrong that wasn't a number or division by zero.")

    finally:
        # The finally block always executes, regardless of whether an exception occurred or not.
        print("\n--- End of Division Operation ---")

# --- Run the program ---
perform_division()

print("\n--- Another attempt with different inputs ---")
perform_division()
# Out:
# --- Division Calculator ---
# Enter the first number: 11
# Enter the second number: 22
# Result of division: 11.0 / 22.0 = 0.5
#
# --- End of Division Operation ---
#
# --- Another attempt with different inputs ---
# --- Division Calculator ---
# Enter the first number: 11
# Enter the second number: 22
# Result of division: 11.0 / 22.0 = 0.5
#
# --- End of Division Operation ---

# %% [markdown]
# Q.13)How would you check if a file exists before attempting to read it in Python?

# %% [markdown]
# In Python, there are a few robust ways to check if a file exists before attempting to read it. This is good practice to prevent FileNotFoundError and make your program more resilient.
#
# Here are the most common and recommended methods:
#
# Method 1: Using os.path.exists() or os.path.isfile()
# The os module provides functions for interacting with the operating system, including file system operations.
#
# os.path.exists(path): Checks if a path (which can be a file or a directory) exists. Returns True if it exists, False otherwise.
# os.path.isfile(path): Checks if a path exists and is a regular file. Returns True if it's an existing file, False otherwise (e.g., if it's a directory or doesn't exist). This is generally preferred if you specifically want to read a file.

# %%
import os

file_path = "my_document.txt"

# Create a dummy file for demonstration (optional)
with open(file_path, 'w') as f:
    f.write("Hello, this is a test file.")

print(f"Checking for file: '{file_path}'")

# Using os.path.exists()
if os.path.exists(file_path):
    print("Method 1 (os.path.exists): File exists!")
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            print("File content:\n", content)
    except Exception as e:
        print(f"An error occurred while reading: {e}")
else:
    print("Method 1 (os.path.exists): File does not exist.")

print("-" * 30)

# Using os.path.isfile() - more specific for files
if os.path.isfile(file_path):
    print("Method 1 (os.path.isfile): File exists and is a regular file!")
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            print("File content:\n", content)
    except Exception as e:
        print(f"An error occurred while reading: {e}")
else:
    print("Method 1 (os.path.isfile): File does not exist or is not a regular file.")

# Test with a non-existent file
non_existent_file = "non_existent.txt"
print(f"\nChecking for non-existent file: '{non_existent_file}'")
if os.path.isfile(non_existent_file):
    print(f"File '{non_existent_file}' exists.")
else:
    print(f"File '{non_existent_file}' does not exist.")

# Clean up the dummy file (optional)
if os.path.exists(file_path):
    os.remove(file_path)
# Out:
# Checking for file: 'my_document.txt'
# Method 1 (os.path.exists): File exists!
# File content:
#  Hello, this is a test file.
# ------------------------------
# Method 1 (os.path.isfile): File exists and is a regular file!
# File content:
#  Hello, this is a test file.
#
# Checking for non-existent file: 'non_existent.txt'
# File 'non_existent.txt' does not exist.

# %% [markdown]
# Method 2: Using pathlib (Modern Pythonic Way - Python 3.4+)
# The pathlib module provides an object-oriented way to interact with file system paths, which is often considered more intuitive and powerful than os.path.

# %%
from pathlib import Path

file_path_str = "another_document.txt"
file_path = Path(file_path_str) # Create a Path object

# Create a dummy file for demonstration (optional)
with open(file_path, 'w') as f:
    f.write("This is another test document.")

print(f"\nChecking for file: '{file_path_str}' using pathlib")

if file_path.exists():
    print("Method 2 (pathlib.Path.exists): File exists!")
    if file_path.is_file(): # Check if it's specifically a file
        print("Method 2 (pathlib.Path.is_file): It is indeed a file!")
        try:
            with open(file_path, 'r') as file:
                content = file.read()
                print("File content:\n", content)
        except Exception as e:
            print(f"An error occurred while reading: {e}")
    else:
        print("Method 2 (pathlib.Path.is_file): It exists, but is not a regular file (e.g., it's a directory).")
else:
    print("Method 2 (pathlib.Path.exists): File does not exist.")

# Test with a non-existent file
non_existent_file_path = Path("yet_another_non_existent.txt")
print(f"\nChecking for non-existent file: '{non_existent_file_path}'")
if non_existent_file_path.is_file():
    print(f"File '{non_existent_file_path}' exists.")
else:
    print(f"File '{non_existent_file_path}' does not exist.")

# Clean up the dummy file (optional)
if file_path.exists():
    file_path.unlink() # For pathlib, use unlink() to delete a file
# Out:
# Checking for file: 'another_document.txt' using pathlib
# Method 2 (pathlib.Path.exists): File exists!
# Method 2 (pathlib.Path.is_file): It is indeed a file!
# File content:
#  This is another test document.
#
# Checking for non-existent file: 'yet_another_non_existent.txt'
# File 'yet_another_non_existent.txt' does not exist.

# %% [markdown]
# Q.14)Write a program that uses the logging module to log both informational and error messages.

# %%
"Program to Demonstrate Logging Informational and Error Messages"

import logging
import os

# --- 1. Basic Configuration for Logging ---
# This sets up the root logger. It's often good practice to do this once
# at the beginning of your application.

# Define the log file path
log_file_name = "application.log"

# Check if the log file exists and delete it to start fresh for demonstration
if os.path.exists(log_file_name):
    os.remove(log_file_name)

logging.basicConfig(
    level=logging.INFO,  # Set the minimum logging level to INFO
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file_name),  # Log messages to a file
        logging.StreamHandler()              # Also log messages to the console
    ]
)

# --- 2. Get a Logger Instance ---
# It's recommended to get a logger instance for each module/file,
# typically named after the module (e.g., __name__).
# This allows for more granular control and better traceability.
logger = logging.getLogger(__name__)

# --- 3. Example Functions Demonstrating Logging ---

def process_data(data_list):
    """
    Simulates processing a list of data, logging informational messages.
    """
    logger.info("Starting data processing...")
    if not data_list:
        logger.warning("Data list is empty. Nothing to process.")
        return

    for item in data_list:
        if item % 2 == 0:
            logger.debug(f"Processing even item: {item}") # DEBUG messages won't show with level=INFO
        else:
            logger.info(f"Processing item: {item}")
    logger.info("Data processing completed.")

def perform_calculation(num1, num2):
    """
    Attempts a division operation, logging errors if issues occur.
    """
    logger.info(f"Attempting calculation: {num1} / {num2}")
    try:
        result = num1 / num2
        logger.info(f"Calculation successful: {num1} / {num2} = {result}")
        return result
    except ZeroDivisionError:
        logger.error(f"Error: Attempted to divide by zero! ({num1} / {num2})")
        # In a real application, you might raise the error again or handle it differently
        return None
    except TypeError:
        logger.error(f"Error: Invalid type for calculation. Expected numbers, got '{type(num1).__name__}' and '{type(num2).__name__}'.")
        return None
    except Exception as e:
        logger.critical(f"A critical and unexpected error occurred during calculation: {e}", exc_info=True)
        # exc_info=True adds exception information (traceback) to the log
        return None

# --- 4. Main Program Execution ---
if __name__ == "__main__":
    logger.info("Application started.")

    # Scenario 1: Successful data processing
    data_sample_1 = [10, 25, 33, 40]
    process_data(data_sample_1)
    print("\n")

    # Scenario 2: Empty data list (warning)
    data_sample_2 = []
    process_data(data_sample_2)
    print("\n")

    # Scenario 3: Successful calculation
    perform_calculation(100, 5)
    print("\n")

    # Scenario 4: Division by zero (error)
    perform_calculation(50, 0)
    print("\n")

    # Scenario 5: Invalid types for calculation (error)
    perform_calculation("abc", 10)
    print("\n")

    # Scenario 6: Another successful calculation
    perform_calculation(7.5, 2.5)

    logger.info("Application finished.")
# Out:
# WARNING:__main__:Data list is empty. Nothing to process.
# ERROR:__main__:Error: Attempted to divide by zero! (50 / 0)
# ERROR:__main__:Error: Invalid type for calculation. Expected numbers, got 'str' and 'int'.

# %% [markdown]
# Q.15)Write a Python program that prints the content of a file and handles the case when the file is empty.

# %%
import os

def print_file_content(file_path):
    """
    Prints the content of a file.
    Handles cases where the file does not exist or is empty.

    Args:
        file_path (str): The path to the file.
    """
    print(f"\n--- Attempting to read file: '{file_path}' ---")

    # 1. Check if the file exists using os.path.exists()
    if not os.path.exists(file_path):
        print(f"Error: The file '{file_path}' does not exist.")
        return

    # 2. Try to open and read the file
    try:
        with open(file_path, 'r') as file:
            content = file.read()

            # 3. Check if the file content is empty
            if not content: # An empty string evaluates to False in a boolean context
                print(f"The file '{file_path}' exists but is empty.")
            else:
                print(f"Content of '{file_path}':")
                print(content)

    except Exception as e:
        # Catch any other potential errors during file reading (e.g., permission denied)
        print(f"An error occurred while reading the file '{file_path}': {e}")

# --- Test Cases ---

# Create dummy files for testing
test_file_1_name = "test_file_with_content.txt"
with open(test_file_1_name, 'w') as f:
    f.write("This is the first line.\n")
    f.write("This is the second line.")

test_file_2_name = "empty_file.txt"
# Creating an empty file
open(test_file_2_name, 'w').close()

test_file_3_name = "non_existent_file.txt" # This file will not be created


# Test Case 1: File with content
print_file_content(test_file_1_name)

# Test Case 2: Empty file
print_file_content(test_file_2_name)

# Test Case 3: Non-existent file
print_file_content(test_file_3_name)

# Test Case 4: Another file with content
test_file_4_name = "another_content.txt"
with open(test_file_4_name, 'w') as f:
    f.write("Hello from Ajmer!\n")
    f.write("Current time: 2025-06-05 09:00:33 AM IST")
print_file_content(test_file_4_name)


# --- Clean up dummy files (optional) ---
print("\n--- Cleaning up test files ---")
if os.path.exists(test_file_1_name):
    os.remove(test_file_1_name)
    print(f"Removed '{test_file_1_name}'")
if os.path.exists(test_file_2_name):
    os.remove(test_file_2_name)
    print(f"Removed '{test_file_2_name}'")
if os.path.exists(test_file_4_name):
    os.remove(test_file_4_name)
    print(f"Removed '{test_file_4_name}'")
# Out:
# --- Attempting to read file: 'test_file_with_content.txt' ---
# Content of 'test_file_with_content.txt':
# This is the first line.
# This is the second line.
#
# --- Attempting to read file: 'empty_file.txt' ---
# The file 'empty_file.txt' exists but is empty.
#
# --- Attempting to read file: 'non_existent_file.txt' ---
# Error: The file 'non_existent_file.txt' does not exist.
#
# --- Attempting to read file: 'another_content.txt' ---
# Content of 'another_content.txt':
# Hello from Ajmer!
# Current time: 2025-06-05 09:00:33 AM IST
#
# --- Cleaning up test files ---
# Removed 'test_file_with_content.txt'
# Removed 'empty_file.txt'
# Removed 'another_content.txt'

# %% [markdown]
# Q.16)Demonstrate how to use memory profiling to check the memory usage of a small program.

# %% [markdown]
# Method 1: Using tracemalloc (Built-in)
# tracemalloc allows you to track memory allocations and see a traceback of where specific memory blocks were allocated.
#
# Installation: No installation needed,

# %%
import tracemalloc
import sys
import gc # Garbage Collector

def demonstrate_tracemalloc():
    print("--- Demonstrating tracemalloc for Memory Profiling ---")

    # 1. Start tracking memory allocations
    tracemalloc.start()
    print("tracemalloc started.")

    # Get initial memory usage
    initial_current, initial_peak = tracemalloc.get_traced_memory()
    print(f"Initial memory usage: Current={initial_current / 1024:.2f} KB, Peak={initial_peak / 1024:.2f} KB")

    # --- Small program logic ---
    my_list = []
    num_elements = 100000

    print(f"\nAllocating {num_elements} integers into a list...")
    for i in range(num_elements):
        my_list.append(i) # Appending integers

    # Get memory usage after allocation
    after_alloc_current, after_alloc_peak = tracemalloc.get_traced_memory()
    print(f"After allocation: Current={after_alloc_current / 1024:.2f} KB, Peak={after_alloc_peak / 1024:.2f} KB")
    print(f"Memory increased by: {(after_alloc_current - initial_current) / 1024:.2f} KB")

    # Let's create another data structure
    my_dict = {f"key_{i}": f"value_{i}" for i in range(50000)}
    print(f"\nAllocating {len(my_dict)} key-value pairs into a dictionary...")

    # Get memory usage after another allocation
    final_current, final_peak = tracemalloc.get_traced_memory()
    print(f"After dictionary allocation: Current={final_current / 1024:.2f} KB, Peak={final_peak / 1024:.2f} KB")
    print(f"Memory increased by (since start): {(final_current - initial_current) / 1024:.2f} KB")


    # --- Analyze snapshots ---
    print("\n--- Top 10 Memory Allocations (by file and line) ---")
    # Take a snapshot of current allocations
    snapshot = tracemalloc.take_snapshot()
    top_stats = snapshot.statistics('lineno') # Group by line number

    for stat in top_stats[:10]:
        print(stat)

    # Optional: Analyze differences between snapshots
    print("\n--- Memory Differences (Initial vs. Final) ---")
    initial_snapshot = tracemalloc.take_snapshot()
    # Perform some operations that might release memory (e.g., delete large objects)
    del my_list
    del my_dict
    gc.collect() # Force garbage collection

    final_snapshot_after_del = tracemalloc.take_snapshot()
    top_diffs = final_snapshot_after_del.compare_to(initial_snapshot, 'lineno')

    # Note: Differences might be tricky as Python's GC can reclaim memory at various times.
    # For more reliable diffs, run the code segment you want to profile between `start()` and `stop()`.

    print("\n--- Top 10 Memory Differences (after object deletion) ---")
    for stat in top_diffs[:10]:
        print(stat)


    # 2. Stop tracking memory allocations
    tracemalloc.stop()
    print("\ntracemalloc stopped.")
    print(f"Final memory state (after stop): Current={tracemalloc.get_traced_memory()[0] / 1024:.2f} KB")


if __name__ == "__main__":
    demonstrate_tracemalloc()
# Out:
# --- Demonstrating tracemalloc for Memory Profiling ---
# tracemalloc started.
# Initial memory usage: Current=0.00 KB, Peak=0.20 KB
#
# Allocating 100000 integers into a list...
# After allocation: Current=3902.98 KB, Peak=3903.02 KB
# Memory increased by: 3902.98 KB
#
# Allocating 50000 key-value pairs into a dictionary...
# After dictionary allocation: Current=11521.19 KB, Peak=11732.77 KB
# Memory increased by (since start): 11521.19 KB
#
# --- Top 10 Memory Allocations (by file and line) ---
# <ipython-input-18-68173295237d>:30: size=7617 KiB, count=100001, average=78 B
# <ipython-input-18-68173295237d>:21: size=3117 KiB, count=99743, average=32 B
# <ipython-input-18-68173295237d>:22: size=782 KiB, count=1, average=782 KiB
# /usr/local/lib/python3.11/dist-packages/google/colab/_variable_inspector.py:28: size=1520 B, count=1, average=1520 B
# /usr/local/lib/python3.11/dist-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_comm.py:653: size=576 B, count=2, average=288 B
# ...

# %% [markdown]
# Q.17)Write a Python program to create and write a list of numbers to a file, one number per line.

# %%
# Define a list of numbers
numbers = [10, 20, 30, 40, 50]

# Open a file in write mode
with open("numbers.txt", "w") as file:
    for number in numbers:
        file.write(str(number) + "\n")

print("Numbers have been written to 'numbers.txt'.")
# Out:
# Numbers have been written to 'numbers.txt'.

# %% [markdown]
# Q.18) How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler

# Set up a rotating file handler
log_file = "app.log"
max_size = 1 * 1024 * 1024  # 1MB
backup_count = 3  # Number of old log files to keep

# Create a rotating file handler
handler = RotatingFileHandler(log_file, maxBytes=max_size, backupCount=backup_count)

# Set logging format
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Set up the root logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # Set desired log level
logger.addHandler(handler)

# Example usage
for i in range(10000):
    logger.info(f"This is log entry number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:This is log entry number 5000
# INFO:root:This is log entry number 5001
# INFO:root:This is log entry number 5002
# INFO:root:This is log entry number 5003
# INFO:root:This is log entry number 5004
# INFO:root:This is log entry number 5005
# INFO:root:This is log entry number 5006
# INFO:root:This is log entry number 5007
# INFO:root:This is log entry number 5008
# INFO:root:This is log entry number 5009
# INFO:root:This is log entry number 5010
# INFO:root:This is log entry number 5011
# INFO:root:This is log entry number 5012
# INFO:root:This is log entry number 5013
# INFO:root:This is log entry number 5014
# INFO:root:This is log entry number 5015
# INFO:root:This is log entry number 5016
# INFO:root:This is log entry number 5017
# INFO:root:This is log entry number 5018
# INFO:root:This is log entry number 5019
# INFO:root:This is log entry number 5020
# INFO:root:This is log entry number 5021
# ...

# %% [markdown]
# Q.19)Write a program that handles both IndexError and KeyError using a try-except block.

# %%
def handle_errors():
    my_list = [10, 20, 30]
    my_dict = {"a": 1, "b": 2}

    try:
        # Trying to access an index that doesn't exist
        print("List element at index 5:", my_list[5])

        # Trying to access a key that doesn't exist
        print("Value for key 'z':", my_dict["z"])

    except IndexError as ie:
        print("IndexError occurred:", ie)

    except KeyError as ke:
        print("KeyError occurred:", ke)

# Run the function
handle_errors()
# Out:
# IndexError occurred: list index out of range

# %% [markdown]
# Q.20)How would you open a file and read its contents using a context manager in Python?

# %%
def read_file_with_context_manager(file_path):
    """
    Opens a file using a context manager and reads its entire content.
    Handles FileNotFoundError if the file does not exist.

    Args:
        file_path (str): The path to the file to be read.

    Returns:
        str: The content of the file if successful, None otherwise.
    """
    try:
        # The 'with' statement ensures the file is properly closed
        # even if an error occurs during reading.
        with open(file_path, 'r') as file:
            # 'file' is the file object, automatically closed when exiting 'with' block
            content = file.read()
            print(f"Successfully read content from '{file_path}':")
            print("-" * 30)
            print(content)
            print("-" * 30)
            return content
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' was not found.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred while reading '{file_path}': {e}")
        return None

# --- Demonstration ---

# 1. Create a dummy file for testing
test_file_name = "sample_document.txt"
with open(test_file_name, 'w') as f:
    f.write("This is the first line of the sample document.\n")
    f.write("Here's the second line.\n")
    f.write("And a final third line.")

# Read the content of the existing file
read_file_with_context_manager(test_file_name)

print("\n" + "="*50 + "\n")

# Try to read a non-existent file
non_existent_file_name = "non_existent_document.txt"
read_file_with_context_manager(non_existent_file_name)

# --- Clean up the dummy file (optional) ---
import os
if os.path.exists(test_file_name):
    os.remove(test_file_name)
    print(f"\nCleaned up: '{test_file_name}'")
# Out:
# Successfully read content from 'sample_document.txt':
# ------------------------------
# This is the first line of the sample document.
# Here's the second line.
# And a final third line.
# ------------------------------
#
# ...
#
# Error: The file 'non_existent_document.txt' was not found.
#
# Cleaned up: 'sample_document.txt'

# %% [markdown]
# Q.21)Write a Python program that reads a file and prints the number of occurrences of a specific word.

# %%
import os
import re # Import the regular expression module for word boundary handling

def count_word_occurrences(file_path, target_word, case_sensitive=False):
    """
    Reads a text file and counts the occurrences of a specific word.

    Args:
        file_path (str): The path to the text file.
        target_word (str): The word to search for.
        case_sensitive (bool): If True, the search is case-sensitive.
                               If False, the search is case-insensitive.
                               Defaults to False.

    Returns:
        int: The number of occurrences of the target word.
             Returns -1 if the file is not found or an error occurs.
    """
    if not os.path.exists(file_path):
        print(f"Error: The file '{file_path}' does not exist.")
        return -1

    count = 0
    search_word = target_word
    if not case_sensitive:
        search_word = target_word.lower() # Convert target word to lowercase for case-insensitive comparison

    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                # For robust word counting, we often want to match whole words.
                # We can convert the line to lowercase here for case-insensitive matching.
                processed_line = line
                if not case_sensitive:
                    processed_line = line.lower()

                # Option 1: Simple string count (may count substrings)
                # count += processed_line.count(search_word)

                # Option 2: Using regex for whole word matching (recommended)
                # \b matches a word boundary (e.g., prevents "apple" from matching "pineapple")
                # re.findall returns a list of all non-overlapping matches
                pattern = r'\b' + re.escape(search_word) + r'\b' # re.escape handles special regex chars in target_word
                matches = re.findall(pattern, processed_line)
                count += len(matches)

        return count

    except FileNotFoundError: # This is technically caught by os.path.exists, but good to have
        print(f"Error: The file '{file_path}' was not found.")
        return -1
    except Exception as e:
        print(f"An unexpected error occurred while reading the file: {e}")
        return -1

# --- Main Program Execution ---
if __name__ == "__main__":
    # 1. Create a dummy text file for demonstration
    file_name = "sample_text.txt"
    content = """
    Python is a popular programming language.
    It is widely used for web development, data analysis, machine learning, and more.
    Many Python developers find Python code to be clean and readable.
    The Python community is very supportive.
    Let's count how many times "python" appears, and "count".
    This is also about COUNTING.
    """
    with open(file_name, 'w', encoding='utf-8') as f:
        f.write(content.strip()) # .strip() removes leading/trailing whitespace

    print(f"Created '{file_name}' for demonstration.")

    # 2. Define the word to search for
    word_to_find = "Python"

    # 3. Test Case 1: Case-insensitive search
    print(f"\n--- Searching for '{word_to_find}' (case-insensitive) ---")
    occurrences_ci = count_word_occurrences(file_name, word_to_find, case_sensitive=False)
    if occurrences_ci != -1:
        print(f"The word '{word_to_find}' appears {occurrences_ci} times (case-insensitive).")

    # Expected: 5 (Python, Python, Python, python, Python)

    # 4. Test Case 2: Case-sensitive search
    print(f"\n--- Searching for '{word_to_find}' (case-sensitive) ---")
    occurrences_cs = count_word_occurrences(file_name, word_to_find, case_sensitive=True)
    if occurrences_cs != -1:
        print(f"The word '{word_to_find}' appears {occurrences_cs} times (case-sensitive).")
    # Expected: 4 (Python, Python, Python, Python)

    # 5. Test Case 3: Another word, case-insensitive (and demonstrating word boundaries)
    word_to_find_2 = "count"
    print(f"\n--- Searching for '{word_to_find_2}' (case-insensitive, whole word) ---")
    occurrences_count = count_word_occurrences(file_name, word_to_find_2, case_sensitive=False)
    if occurrences_count != -1:
        print(f"The word '{word_to_find_2}' appears {occurrences_count} times (case-insensitive, whole word).")
    # Expected: 2 (count, COUNTING) - should not match "account" if present in file

    # 6. Test Case 4: Non-existent file
    print(f"\n--- Searching in a non-existent file ---")
    count_word_occurrences("non_existent_file.txt", "test")

    # --- Clean up the dummy file ---
    if os.path.exists(file_name):
        os.remove(file_name)
        print(f"\nCleaned up '{file_name}'.")
# Out:
# Created 'sample_text.txt' for demonstration.
#
# --- Searching for 'Python' (case-insensitive) ---
# The word 'Python' appears 5 times (case-insensitive).
#
# --- Searching for 'Python' (case-sensitive) ---
# The word 'Python' appears 4 times (case-sensitive).
#
# --- Searching for 'count' (case-insensitive, whole word) ---
# The word 'count' appears 2 times (case-insensitive, whole word).
#
# --- Searching in a non-existent file ---
# Error: The file 'non_existent_file.txt' does not exist.
#
# Cleaned up 'sample_text.txt'.

# %% [markdown]
# Q.22)How can you check if a file is empty before attempting to read its contents?

# %%
import os
from pathlib import Path

def is_file_empty_getsize(file_path):
    """
    Checks if a file is empty using os.path.getsize().
    Returns True if empty, False if not empty, None if file doesn't exist or error.
    """
    try:
        if not os.path.exists(file_path):
            print(f"'{file_path}': File does not exist.")
            return None

        file_size = os.path.getsize(file_path)
        return file_size == 0
    except OSError as e:
        print(f"Error checking size of '{file_path}': {e}")
        return None

def is_file_empty_read_char(file_path):
    """
    Checks if a file is empty by attempting to read its first character.
    Returns True if empty, False if not empty, None if file doesn't exist or error.
    """
    try:
        if not os.path.exists(file_path):
            print(f"'{file_path}': File does not exist.")
            return None

        with open(file_path, 'r', encoding='utf-8') as file:
            first_char = file.read(1) # Read only 1 character
            return not bool(first_char) # If an empty string is returned, it's empty
    except FileNotFoundError: # Caught by os.path.exists, but good for robustness
        print(f"'{file_path}': File not found.")
        return None
    except Exception as e:
        print(f"Error reading first char of '{file_path}': {e}")
        return None

def is_file_empty_pathlib(file_path):
    """
    Checks if a file is empty using pathlib.Path.stat().st_size.
    Returns True if empty, False if not empty, None if file doesn't exist or error.
    """
    try:
        path_obj = Path(file_path)
        if not path_obj.exists():
            print(f"'{file_path}': File does not exist.")
            return None

        return path_obj.stat().st_size == 0
    except OSError as e:
        print(f"Error checking size of '{file_path}' with pathlib: {e}")
        return None


def process_file(file_path):
    """
    Demonstrates how to process a file only if it's not empty.
    Uses os.path.getsize() for the check.
    """
    print(f"\n--- Processing '{file_path}' ---")

    is_empty = is_file_empty_getsize(file_path) # Choose your preferred method here

    if is_empty is None: # An error occurred or file doesn't exist
        print(f"Cannot process '{file_path}' due to an error or non-existence.")
        return
    elif is_empty:
        print(f"'{file_path}' is empty. Skipping content reading.")
    else:
        print(f"'{file_path}' is not empty. Reading content...")
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read()
                print("Content:")
                print(content)
        except Exception as e:
            print(f"An error occurred while reading content of '{file_path}': {e}")


# --- Main Demonstration ---
if __name__ == "__main__":
    # Create dummy files for testing
    empty_file_name = "empty_test.txt"
    non_empty_file_name = "non_empty_test.txt"
    non_existent_file_name = "does_not_exist.txt"

    # Create an empty file
    open(empty_file_name, 'w').close()
    print(f"Created empty file: '{empty_file_name}'")

    # Create a non-empty file
    with open(non_empty_file_name, 'w', encoding='utf-8') as f:
        f.write("Hello, World!\n")
        f.write("This file has some content.")
    print(f"Created non-empty file: '{non_empty_file_name}'")

    print("\n--- Using os.path.getsize() ---")
    print(f"Is '{empty_file_name}' empty? {is_file_empty_getsize(empty_file_name)}")
    print(f"Is '{non_empty_file_name}' empty? {is_file_empty_getsize(non_empty_file_name)}")
    print(f"Is '{non_existent_file_name}' empty? {is_file_empty_getsize(non_existent_file_name)}")

    print("\n--- Using read(1) ---")
    print(f"Is '{empty_file_name}' empty? {is_file_empty_read_char(empty_file_name)}")
    print(f"Is '{non_empty_file_name}' empty? {is_file_empty_read_char(non_empty_file_name)}")
    print(f"Is '{non_existent_file_name}' empty? {is_file_empty_read_char(non_existent_file_name)}")

    print("\n--- Using pathlib.Path.stat().st_size ---")
    print(f"Is '{empty_file_name}' empty? {is_file_empty_pathlib(empty_file_name)}")
    print(f"Is '{non_empty_file_name}' empty? {is_file_empty_pathlib(non_empty_file_name)}")
    print(f"Is '{non_existent_file_name}' empty? {is_file_empty_pathlib(non_existent_file_name)}")


    # Demonstrate actual file processing flow
    process_file(empty_file_name)
    process_file(non_empty_file_name)
    process_file(non_existent_file_name)

    # Clean up dummy files
    print("\n--- Cleaning up files ---")
    if os.path.exists(empty_file_name):
        os.remove(empty_file_name)
        print(f"Removed '{empty_file_name}'")
    if os.path.exists(non_empty_file_name):
        os.remove(non_empty_file_name)
        print(f"Removed '{non_empty_file_name}'")
# Out:
# Created empty file: 'empty_test.txt'
# Created non-empty file: 'non_empty_test.txt'
#
# --- Using os.path.getsize() ---
# Is 'empty_test.txt' empty? True
# Is 'non_empty_test.txt' empty? False
# 'does_not_exist.txt': File does not exist.
# Is 'does_not_exist.txt' empty? None
#
# --- Using read(1) ---
# Is 'empty_test.txt' empty? True
# Is 'non_empty_test.txt' empty? False
# 'does_not_exist.txt': File does not exist.
# Is 'does_not_exist.txt' empty? None
#
# --- Using pathlib.Path.stat().st_size ---
# Is 'empty_test.txt' empty? True
# Is 'non_empty_test.txt' empty? False
# 'does_not_exist.txt': File does not exist.
# Is 'does_not_exist.txt' empty? None
#
# --- Processing 'empty_test.txt' ---
# 'empty_test.txt' is empty. Skipping content reading.
#
# --- Processing 'non_empty_test.txt' ---
# 'non_empty_test.txt' is not empty. Reading content...
# Content:
# Hello, World!
# This file has some content.
#
# --- Processing 'does_not_exist.txt' ---
# ...

# %% [markdown]
# Q.23)Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

# Configure logging to write to a file with the level ERROR
logging.basicConfig(filename='error_log.txt',
                    level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

def read_file(filename):
    try:
        with open(filename, 'r') as file:
            contents = file.read()
            print(contents)
    except (FileNotFoundError, IOError) as e:
        logging.error(f"Error occurred while handling the file '{filename}': {e}")
        print("An error occurred. Please check the log file for details.")

# Example usage
read_file('non_existent_file.txt')
# Out:
# ERROR:root:Error occurred while handling the file 'non_existent_file.txt': [Errno 2] No such file or directory: 'non_existent_file.txt'
# An error occurred. Please check the log file for details.
